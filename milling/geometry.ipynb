# %% [markdown]
# # Geometry Definition using OpenCASCADE (OCC) and GMSH
#
# <b>Goals:</b>
#
# We wish to generate a generate a geometry with smooth curves to avoid observed nuissances in the boundary layer mesh generation. We thus wish to understand how to apply the OpenCascade function <i>occ.fillet2D()</i>. This function is explained at [OpenCascade Modeling Algorithms](https://old.opencascade.com/doc/occt-6.7.0/overview/html/user_guides__modeling_algos.html);
#
# We wish to export the STL file per patch. To do so, go to "File -> Export" (very bottom of the File menu) and select .stl format. When prompted, select "Per physical surface".
#
# <b>Notes:</b>
# 1. This version uses Julia as scripting language. It might be easier using Python.

# %% [markdown]
# ## Import Packages

# %%
try
    using Gmsh: Gmsh, gmsh
catch
    using gmsh
end 

using Plots

# %% [markdown]
# ## Section 1: Introduction

# %%
# this shows how to consult documentation 
#?gmsh.model.occ.addRectangle

# %% [markdown]
# ## Section 2: Tutorial T19 (Original Version) Uses the Function Fillet()
#
# This [GMSH t19.jl](https://gitlab.onelab.info/gmsh/gmsh/blob/gmsh_4_15_0/tutorials/julia/t19.jl).
# 1. L43: why is <i>model.getBoundary</i> called twice?

# %%
should_finalize = Gmsh.initialize()

gmsh.model.add("t19")

# Volumes can be constructed from (closed) curve loops thanks to the
# `addThruSections()' function
gmsh.model.occ.addCircle(0, 0, 0, 0.5, 1)
gmsh.model.occ.addCurveLoop([1], 1)
gmsh.model.occ.addCircle(0.1, 0.05, 1, 0.1, 2)
gmsh.model.occ.addCurveLoop([2], 2)
gmsh.model.occ.addCircle(-0.1, -0.1, 2, 0.3, 3)
gmsh.model.occ.addCurveLoop([3], 3)
gmsh.model.occ.addThruSections([1, 2, 3], 1)
gmsh.model.occ.synchronize()

# We can also force the creation of ruled surfaces:
gmsh.model.occ.addCircle(2 + 0, 0, 0, 0.5, 11)
gmsh.model.occ.addCurveLoop([11], 11)
gmsh.model.occ.addCircle(2 + 0.1, 0.05, 1, 0.1, 12)
gmsh.model.occ.addCurveLoop([12], 12)
gmsh.model.occ.addCircle(2 - 0.1, -0.1, 2, 0.3, 13)
gmsh.model.occ.addCurveLoop([13], 13)
gmsh.model.occ.addThruSections([11, 12, 13], 11, true, true)
gmsh.model.occ.synchronize()

# We copy the first volume, and fillet all its edges:
out = gmsh.model.occ.copy([(3, 1)])
gmsh.model.occ.translate(out, 4, 0, 0)
gmsh.model.occ.synchronize()
e = gmsh.model.getBoundary(gmsh.model.getBoundary(out), false)
gmsh.model.occ.fillet([out[1][2]], [abs(i[2]) for i in e], [0.1])
gmsh.model.occ.synchronize()

# OpenCASCADE also allows general extrusions along a smooth path. Let's first
# define a spline curve:
nturns = 1.
npts = 20
r = 1.
h = 1. * nturns
p = []
for i in 0:npts-1
    theta = i * 2 * pi * nturns / npts
    gmsh.model.occ.addPoint(r * cos(theta), r * sin(theta),
                            i * h / npts, 1, 1000 + i)
    push!(p, 1000 + i)
end
gmsh.model.occ.addSpline(p, 1000)

# A wire is like a curve loop, but open:
gmsh.model.occ.addWire([1000], 1000)

# We define the shape we would like to extrude along the spline (a disk):
gmsh.model.occ.addDisk(1, 0, 0, 0.2, 0.2, 1000)
gmsh.model.occ.rotate([(2, 1000)], 0, 0, 0, 1, 0, 0, pi / 2)

# We extrude the disk along the spline to create a pipe (other sweeping types
# can be specified; try e.g. "Frenet" instead of "DiscreteTrihedron"):
gmsh.model.occ.addPipe([(2, 1000)], 1000, "DiscreteTrihedron")

# We delete the source surface, and increase the number of sub-edges for a
# nicer display of the geometry:
gmsh.model.occ.remove([(2, 1000)])
gmsh.option.setNumber("Geometry.NumSubEdges", 1000)

gmsh.model.occ.synchronize()

# We can activate the calculation of mesh element sizes based on curvature
# (here with a target of 20 elements per 2*Pi radians):
gmsh.option.setNumber("Mesh.MeshSizeFromCurvature", 20)

# We can constraint the min and max element sizes to stay within reasonnable
# values (see `t10.jl' for more details):
gmsh.option.setNumber("Mesh.MeshSizeMin", 0.001)
gmsh.option.setNumber("Mesh.MeshSizeMax", 0.3)

gmsh.model.mesh.generate(3)
gmsh.write("t19.msh")

# Launch the GUI to see the results:
#if (true) gmsh.fltk.run() end 

gmsh.finalize()
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Circle)
# Info    : [ 10%] Meshing curve 2 (Circle)
# Info    : [ 10%] Meshing curve 3 (Circle)
# Info    : [ 20%] Meshing curve 4 (BSpline)
# Info    : [ 20%] Meshing curve 5 (BSpline)
# Info    : [ 30%] Meshing curve 6 (BSpline)
# Info    : [ 30%] Meshing curve 11 (Circle)
# Info    : [ 40%] Meshing curve 12 (Circle)
# Info    : [ 40%] Meshing curve 13 (Circle)
# Info    : [ 40%] Meshing curve 14 (BSpline)
# Info    : [ 50%] Meshing curve 15 (BSpline)
# Info    : [ 50%] Meshing curve 16 (BSpline)
# Info    : [ 60%] Meshing curve 17 (BSpline)
# Info    : [ 60%] Meshing curve 18 (BSpline)
# Info    : [ 70%] Meshing curve 19 (BSpline)
# Info    : [ 70%] Meshing curve 20 (BSpline)
# Info    : [ 70%] Meshing curve 21 (BSpline)
# Info    : [ 80%] Meshing curve 22 (BSpline)
# Info    : [ 80%] Meshing curve 1000 (BSpline)
# Info    : [ 90%] Meshing curve 1001 (Ellipse)
# Info    : [ 90%] Meshing curve 1002 (BSpline)
# Info    : [100%] Meshing curve 1003 (BSpline)
# Info    : [100%] Meshing curve 1004 (BSpline)
# Info    : Done meshing 1D (Wall 0.203795s, CPU 0.203085s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (BSpline surface, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 4 (BSpline surface, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 5 (BSpline surface, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 7 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 8 (BSpline surface, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 9 (BSpline surface, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 10 (BSpline surface, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 11 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 12 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 1001 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 1002 (BSpline surface, Frontal-Delaunay)
# Info    : [100%] Meshing surface 1003 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.341677s, CPU 0.336802s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 4 volumes with 4 connected components
# Info    : Tetrahedrizing 1095 nodes...
# Info    : Done tetrahedrizing 1103 nodes (Wall 0.00653883s, CPU 0.006436s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.0160581s, CPU 0.014808s)
# Info    : Found volume 1
# Info    : It. 0 - 0 nodes created - worst tet radius 3.36416 (nodes removed 0 0)
# Info    : 3D refinement terminated (8364 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 5863 tetrahedra created in 0.010957 sec. (535089 tets/s)
# Info    : 0 node relocations
# Info    : Tetrahedrizing 955 nodes...
# Info    : Done tetrahedrizing 963 nodes (Wall 0.00529308s, CPU 0.005283s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.0113888s, CPU 0.011316s)
# Info    : Found volume 11
# Info    : It. 0 - 0 nodes created - worst tet radius 3.68498 (nodes removed 0 0)
# Info    : 3D refinement terminated (8318 nodes total):
# Info    :  - 1 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 5177 tetrahedra created in 0.0100861 sec. (513279 tets/s)
# Info    : 0 node relocations
# Info    : Tetrahedrizing 3355 nodes...
# Info    : Done tetrahedrizing 3363 nodes (Wall 0.0191663s, CPU 0.019027s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.0436456s, CPU 0.042913s)
# Info    : Found volume 12
# Info    : It. 0 - 0 nodes created - worst tet radius 8.2199 (nodes removed 0 0)
# Info    : It. 500 - 500 nodes created - worst tet radius 1.74507 (nodes removed 0 0)
# Info    : It. 1000 - 1000 nodes created - worst tet radius 1.44069 (nodes removed 0 0)
# Info    : It. 1500 - 1500 nodes created - worst tet radius 1.27264 (nodes removed 0 0)
# Info    : It. 2000 - 2000 nodes created - worst tet radius 1.17181 (nodes removed 0 0)
# Info    : It. 2500 - 2500 nodes created - worst tet radius 1.09379 (nodes removed 0 0)
# Info    : It. 3000 - 3000 nodes created - worst tet radius 1.04034 (nodes removed 0 0)
# Info    : 3D refinement terminated (11343 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 31640 tetrahedra created in 0.0922097 sec. (343130 tets/s)
# Info    : 0 node relocations
# Info    : Tetrahedrizing 2523 nodes...
# Info    : Done tetrahedrizing 2531 nodes (Wall 0.0147579s, CPU 0.014693s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.0337967s, CPU 0.033475s)
# Info    : Found volume 13
# Info    : It. 0 - 0 nodes created - worst tet radius 3.37797 (nodes removed 0 0)
# Info    : It. 500 - 500 nodes created - worst tet radius 1.28019 (nodes removed 0 0)
# Info    : It. 1000 - 1000 nodes created - worst tet radius 1.06981 (nodes removed 0 0)
# Info    : 3D refinement terminated (9279 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 1 nodes could not be inserted
# Info    :  - 15837 tetrahedra created in 0.0388041 sec. (408127 tets/s)
# Info    : 0 node relocations
# Info    : Done meshing 3D (Wall 0.477221s, CPU 0.468377s)
# Info    : Optimizing mesh...
# Info    : Optimizing volume 1
# Info    : Optimization starts (volume = 0.315269) with worst = 0.0227476 / average = 0.7408:
# Info    : 0.00 < quality < 0.10 :        18 elements
# Info    : 0.10 < quality < 0.20 :        46 elements
# Info    : 0.20 < quality < 0.30 :        82 elements
# Info    : 0.30 < quality < 0.40 :       128 elements
# Info    : 0.40 < quality < 0.50 :       199 elements
# Info    : 0.50 < quality < 0.60 :       353 elements
# Info    : 0.60 < quality < 0.70 :       952 elements
# Info    : 0.70 < quality < 0.80 :      1713 elements
# Info    : 0.80 < quality < 0.90 :      1729 elements
# Info    : 0.90 < quality < 1.00 :       643 elements
# Info    : 143 edge swaps, 3 node relocations (volume = 0.315269): worst = 0.195351 / average = 0.755741 (Wall 0.00102729s, CPU 0.000827s)
# Info    : 144 edge swaps, 4 node relocations (volume = 0.315269): worst = 0.195351 / average = 0.755847 (Wall 0.00116021s, CPU 0.000959s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         1 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :       126 elements
# Info    : 0.40 < quality < 0.50 :       188 elements
# Info    : 0.50 < quality < 0.60 :       350 elements
# Info    : 0.60 < quality < 0.70 :       939 elements
# Info    : 0.70 < quality < 0.80 :      1732 elements
# Info    : 0.80 < quality < 0.90 :      1742 elements
# Info    : 0.90 < quality < 1.00 :       652 elements
# Info    : Optimizing volume 11
# Info    : Optimization starts (volume = 0.455513) with worst = 0.0283731 / average = 0.738294:
# Info    : 0.00 < quality < 0.10 :        18 elements
# Info    : 0.10 < quality < 0.20 :        43 elements
# Info    : 0.20 < quality < 0.30 :        78 elements
# Info    : 0.30 < quality < 0.40 :       107 elements
# Info    : 0.40 < quality < 0.50 :       183 elements
# Info    : 0.50 < quality < 0.60 :       355 elements
# Info    : 0.60 < quality < 0.70 :       876 elements
# Info    : 0.70 < quality < 0.80 :      1396 elements
# Info    : 0.80 < quality < 0.90 :      1532 elements
# Info    : 0.90 < quality < 1.00 :       589 elements
# Info    : 137 edge swaps, 1 node relocations (volume = 0.455513): worst = 0.301374 / average = 0.754419 (Wall 0.000777417s, CPU 0.000764s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :       103 elements
# Info    : 0.40 < quality < 0.50 :       174 elements
# Info    : 0.50 < quality < 0.60 :       357 elements
# Info    : 0.60 < quality < 0.70 :       872 elements
# Info    : 0.70 < quality < 0.80 :      1405 elements
# Info    : 0.80 < quality < 0.90 :      1552 elements
# Info    : 0.90 < quality < 1.00 :       589 elements
# Info    : Optimizing volume 12
# Info    : Optimization starts (volume = 0.287401) with worst = 0.0101265 / average = 0.766326:
# Info    : 0.00 < quality < 0.10 :        78 elements
# Info    : 0.10 < quality < 0.20 :       229 elements
# Info    : 0.20 < quality < 0.30 :       375 elements
# Info    : 0.30 < quality < 0.40 :       580 elements
# Info    : 0.40 < quality < 0.50 :       939 elements
# Info    : 0.50 < quality < 0.60 :      1608 elements
# Info    : 0.60 < quality < 0.70 :      3782 elements
# Info    : 0.70 < quality < 0.80 :      7981 elements
# Info    : 0.80 < quality < 0.90 :     11069 elements
# Info    : 0.90 < quality < 1.00 :      4999 elements
# Info    : 680 edge swaps, 17 node relocations (volume = 0.287401): worst = 0.179448 / average = 0.779946 (Wall 0.00414437s, CPU 0.004072s)
# Info    : 689 edge swaps, 18 node relocations (volume = 0.287401): worst = 0.3001 / average = 0.780139 (Wall 0.00477854s, CPU 0.0047s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :       574 elements
# Info    : 0.40 < quality < 0.50 :       881 elements
# Info    : 0.50 < quality < 0.60 :      1552 elements
# Info    : 0.60 < quality < 0.70 :      3764 elements
# Info    : 0.70 < quality < 0.80 :      8049 elements
# Info    : 0.80 < quality < 0.90 :     11195 elements
# Info    : 0.90 < quality < 1.00 :      4994 elements
# Info    : Optimizing volume 13
# Info    : Optimization starts (volume = 0.741393) with worst = 0.0156048 / average = 0.756382:
# Info    : 0.00 < quality < 0.10 :        38 elements
# Info    : 0.10 < quality < 0.20 :       108 elements
# Info    : 0.20 < quality < 0.30 :       207 elements
# Info    : 0.30 < quality < 0.40 :       348 elements
# Info    : 0.40 < quality < 0.50 :       504 elements
# Info    : 0.50 < quality < 0.60 :       838 elements
# Info    : 0.60 < quality < 0.70 :      2115 elements
# Info    : 0.70 < quality < 0.80 :      4222 elements
# Info    : 0.80 < quality < 0.90 :      5277 elements
# Info    : 0.90 < quality < 1.00 :      2180 elements
# Info    : 350 edge swaps, 2 node relocations (volume = 0.741393): worst = 0.179196 / average = 0.77052 (Wall 0.002024s, CPU 0.001983s)
# Info    : 352 edge swaps, 5 node relocations (volume = 0.741393): worst = 0.223147 / average = 0.770576 (Wall 0.00234312s, CPU 0.002298s)
# Info    : 353 edge swaps, 5 node relocations (volume = 0.741393): worst = 0.290823 / average = 0.770565 (Wall 0.00260213s, CPU 0.00255s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         1 elements
# Info    : 0.30 < quality < 0.40 :       333 elements
# Info    : 0.40 < quality < 0.50 :       464 elements
# Info    : 0.50 < quality < 0.60 :       828 elements
# Info    : 0.60 < quality < 0.70 :      2129 elements
# Info    : 0.70 < quality < 0.80 :      4236 elements
# Info    : 0.80 < quality < 0.90 :      5333 elements
# Info    : 0.90 < quality < 1.00 :      2185 elements
# Info    : Done optimizing mesh (Wall 0.0315542s, CPU 0.030337s)
# Info    : 13638 nodes 73882 elements
# Info    : Writing 't19.msh'...
# Info    : Done writing 't19.msh'

# %% [markdown]
# ## Section 3: Unit square with one fillet extruded in the z-direction

# %%
?gmsh.model.occ.addLine
# Out:
#   gmsh.model.occ.addLine(startTag, endTag, tag = -1)
#
#   Add a straight line segment in the OpenCASCADE CAD representation, between
#   the two points with tags startTag and endTag. If tag is positive, set the
#   tag explicitly; otherwise a new tag is selected automatically. Return the
#   tag of the line.
#
#   Return an integer.
#
#   Types:
#
#     •  startTag: integer
#
#     •  endTag: integer
#
#     •  tag: integer

# %%
#..initialize gmsh 
should_finalize = Gmsh.initialize()

#..generate geometry 
gmsh.option.setNumber("General.Terminal", 1)
gmsh.model.add("square")
#..set mesh density parameter 
lc = .1
zc = 0. 
#..define four points p1, p2, p3 and p4 with tags 1, 2, 3 and 4 via (x,y,z) coordinates 
p1 = gmsh.model.occ.addPoint(0, 0, zc, lc, 1)
p2 = gmsh.model.occ.addPoint(1., 0,  zc, lc, 2)
p3 = gmsh.model.occ.addPoint(1., 1., zc, lc, 3)
p4 = gmsh.model.occ.addPoint(0, 1., zc, lc, 4)
#..define four edges l1, l2, l3 and l4 with tags 1, 2, 3 and 4 by connecting point labels pairwise  
#..the line that connects points with tag i (first argument) and tag i+1 (second argument) has tag i 
l1 = gmsh.model.occ.addLine(1, 2, 1)
l2 = gmsh.model.occ.addLine(2, 3, 2)
l3 = gmsh.model.occ.addLine(3, 4, 3)
l4 = gmsh.model.occ.addLine(4, 1, 4)
#..define a fillet between lines with tag 1 and tag 2 and radius 0.1   
fillet_tag1 = gmsh.model.occ.fillet2D(1,2,0.1)
#..define curved loop by connecting four lines and fillet labels  
loop = gmsh.model.occ.addCurveLoop([1,fillet_tag1, 2, 3, 4], 1)
#..define surface by curved loop 
surf = gmsh.model.occ.addPlaneSurface([1], 1)
#..define volume by extracting the surface in perpendicular direction 
volume = gmsh.model.occ.extrude([(2, surf)], 0, 0, 1)

#..synchronize the CAD model 
gmsh.model.occ.synchronize()

if (true) gmsh.fltk.run() end

#..finalize gmsh 
should_finalize && Gmsh.finalize()
# Out:
# -------------------------------------------------------
# Version       : 4.13.1
# License       : GNU General Public License
# Build OS      : MacOSX-sdk
# Build date    : 19700101
# Build host    : amdci7.julia.csail.mit.edu
# Build options : 64Bit ALGLIB[contrib] ANN[contrib] Bamg Blossom Cairo DIntegration Dlopen DomHex Eigen[contrib] Fltk GMP Gmm[contrib] Hxt Jpeg Kbipack MathEx[contrib] Mesh Metis[contrib] Mmg Mpeg Netgen Nii2mesh ONELAB ONELABMetamodel OpenCASCADE OpenCASCADE-CAF OpenGL OpenMP OptHom Parser Plugins Png Post QuadMeshingTools QuadTri Solver TetGen/BR TinyXML2[contrib] Untangle Voro++[contrib] WinslowUntangler Zlib
# FLTK version  : 1.3.8
# OCC version   : 7.7.2
# Packaged by   : root
# Web site      : https://gmsh.info
# Issue tracker : https://gitlab.onelab.info/gmsh/gmsh/issues
# -------------------------------------------------------
# Info    : Writing '/Users/dlahaye/my_openfoam/milling/provs'...
# Info    : Done writing '/Users/dlahaye/my_openfoam/milling/provs'
# Info    : Writing '/Users/dlahaye/my_openfoam/milling/prova.stl'...
# Info    : Done writing '/Users/dlahaye/my_openfoam/milling/prova.stl'
# 2026-02-04 19:17:13.432 julia[60317:5049829] The class 'NSSavePanel' overrides the method identifier.  This method is implemented by class 'NSWindow'
# false

# %% [markdown]
# ## Section 4: Geometry of mill using 10 points

# %%
#..initialize gmsh 
should_finalize = Gmsh.initialize()

#..generate geometry 
gmsh.option.setNumber("General.Terminal", 1)
gmsh.model.add("square")
#..set mesh density parameter 
lc = .1
zc = 0. 
#..define four points p1, p2, p3 and p4 with tags 1, 2, 3 and 4 via (x,y,z) coordinates 
p1 = gmsh.model.occ.addPoint(0, -0.1, zc, lc, 1)
p2 = gmsh.model.occ.addPoint(2., -0.1,  zc, lc, 2)
p3 = gmsh.model.occ.addPoint(2.5, -0.1, zc, lc, 3)
p4 = gmsh.model.occ.addPoint(2.5, 0., zc, lc, 4)
p5 = gmsh.model.occ.addPoint(2., 0., zc, lc, 5)
p6 = gmsh.model.occ.addPoint(1., 0., zc, lc, 6)
p7 = gmsh.model.occ.addPoint(0.5, 0.4, zc, lc, 7)
p8 = gmsh.model.occ.addPoint(0.25, 1., zc, lc, 8)
p9 = gmsh.model.occ.addPoint(0.25, 2.,  zc, lc, 9)
p10 = gmsh.model.occ.addPoint(0., 2.,  zc, lc, 10)

#..define four edges l1, l2, l3 and l4 with tags 1, 2, 3 and 4 by connecting point labels pairwise  
#..the line that connects points with tag i (first argument) and tag i+1 (second argument) has tag i 
l1 = gmsh.model.occ.addLine(1, 2, 1)
l2 = gmsh.model.occ.addLine(2, 3, 2)
l3 = gmsh.model.occ.addLine(3, 4, 3)
l4 = gmsh.model.occ.addLine(4, 5, 4)
l5 = gmsh.model.occ.addLine(5, 6, 5)
l6 = gmsh.model.occ.addLine(6, 7, 6)
l7 = gmsh.model.occ.addLine(7, 8, 7)
l8 = gmsh.model.occ.addLine(8, 9, 8)
l9 = gmsh.model.occ.addLine(9, 10, 9)
l10 = gmsh.model.occ.addLine(10, 1, 10)
#..define a fillet between lines with tag 1 and tag 2 and radius 0.1 
fillet_tag1 = gmsh.model.occ.fillet2D(5,6,0.5)
fillet_tag2 = gmsh.model.occ.fillet2D(6,7,0.5)
fillet_tag3 = gmsh.model.occ.fillet2D(7,8,0.5)
#..define curved loop by connecting four lines and fillet labels  
loop = gmsh.model.occ.addCurveLoop([1, 2, 3, 4, 5, fillet_tag1, 6, fillet_tag2, 7, fillet_tag3, 8, 9, 10], 12)
#..define surface by curved loop 
surf = gmsh.model.occ.addPlaneSurface([12], 1)
#..define volume by extracting the surface in perpendicular direction 
volume = gmsh.model.occ.extrude([(2, surf)], 0, 0, 1)

#..synchronize the CAD model 
gmsh.model.occ.synchronize()

if (true) gmsh.fltk.run() end

#..finalize gmsh 
should_finalize && Gmsh.finalize()
